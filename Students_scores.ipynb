# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
#     <div style ="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Students Exam Scores
# </p>
# </div>

# %% [markdown]
# ![marks.jpg](attachment:marks.jpg)

# %% [markdown]
# # This dataset includes scores from three test scores of students at a (fictional) public school and a variety of personal and socio-economic factors that may have interaction effects upon them.

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Work Flow
# </p>
# </div>

# %% [markdown]
# # Workflow :
# - Importing the requires libraries
# - loading the data set
# - Basic understanding of data
#    - checking shape
#    - Preview of Data
#    - Data Dictionary (column description)
#    - Checking column types
#    - Checking the Basic Information of Data
# - Preprocessing
#   - checking the missing values
#   - checking the duplicacy
#   - columns conversion
#   - Handling the Missing Values
#   - descriptive stats
# - Exploratory Data Analysis
#   - How many male and female student present in the dataset?
#   - How many male and female student present in the dataset?
#   -  Number of Males and Female student in each group
#   -  Parents Education background
#   -  Distribution Of lunch type
#   -  How many students prepared for the test or not?
#   -  ParentMartialStatus
#   -  Number of siblings of each students
#   -  Highest marks in all subjects
#   - Compare the marks with the parents education
#   - Compare the marks with the ParentMartialStatus
#   - Relationship Between WklyStudyHours and student's score
#   - Is the outliers present in the student'score?
#   - Compare the student's score with the practice test
# - Conclusion

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Import the Required Libraries
# </p>
# </div>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Loading the Data Set
# </p>
# </div>

# %%
df=pd.read_csv("D:\data sets\Expanded_data_with_more_features.csv")

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Basic Understanding of Data
# </div>

# %% [markdown]
# # Checking the Shape

# %%
df.shape

# %% [markdown]
# <h3 align="left"><font color='#CD5C5C'>Observation :: </font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# - there are **30641** rows in the dataset
# - there are **15** columns in the dataset

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Preview of Data
# </p>
# </div>

# %%
df.head(2) # fetching the 5 records

# %% [markdown]
# # Data Dictionary (column description)
# - Gender: Gender of the student (male/female)
# - EthnicGroup: Ethnic group of the student (group A to E)
# - ParentEduc: Parent(s) education background (from some_highschool to master's degree)
# - LunchType: School lunch type (standard or free/reduced)
# - TestPrep: Test preparation course followed (completed or none)
# - ParentMaritalStatus: Parent(s) marital status (married/single/widowed/divorced)
# - PracticeSport: How often the student parctice sport (never/sometimes/regularly))
# - IsFirstChild: If the child is first child in the family or not (yes/no)
# - NrSiblings: Number of siblings the student has (0 to 7)
# - TransportMeans: Means of transport to school (schoolbus/private)
# - WklyStudyHours: Weekly self-study hours(less that 5hrs; between 5 and 10hrs; more than 10hrs)
# - MathScore: math test score(0-100)
# - ReadingScore: reading test score(0-100)
# - WritingScore: writing test score(0-100)

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Checking column types
# </p>
# </div>

# %%
df.dtypes.to_frame().rename(columns={0:"types"}).T
# Out:
#       Unnamed: 0  Gender EthnicGroup ParentEduc LunchType TestPrep  \
# types      int64  object      object     object    object   object
#
#       ParentMaritalStatus PracticeSport IsFirstChild NrSiblings  \
# types              object        object       object    float64
#
#       TransportMeans WklyStudyHours MathScore ReadingScore WritingScore
# types         object         object     int64        int64        int64

# %% [markdown]
# <h3 align="left"><font color='#CD5C5C'>Observation :: </font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">

# %% [markdown]
# - All the columns have **correct** **dtype** so don't need to change

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Checking  Basic information of Data
# </div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# ...

# %% [markdown]
# <h3 align="left"><font color='#CD5C5C'>Observation :: </font></h3>
# <div style="font-family:Georgia;background-color:'black'; font-color:'black',padding:30px; font-size:17px">
#
# *  Some columns have missing values
# *  columns of float types: 1
# *  columns of int types : 4
# *  columns of object types : 10

# %%
df.describe()

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Preprocessing
# </div>

# %% [markdown]
# ## Checking missing values of each columns

# %%
df.isnull().sum()

# %%
for i in df.columns:
    if df[i].isnull().sum()>0:
        print(i,"-----------",df[i].isnull().sum()*100/df.shape[0],"%",df[i].dtype)

# %% [markdown]
# # Drop the irrevalant columns:
# As these columns TransportMeans,PracticeSport,Unnamed: 0 does n't have any link with the score of the student

# %%
df.drop(columns=["TransportMeans","PracticeSport","Unnamed: 0"],inplace=True)

# %% [markdown]
# # Handling the missing values :
# fill all the missing value by **not define**

# %%
df["WklyStudyHours"].unique()

# %%
df["WklyStudyHours"]=df["WklyStudyHours"].fillna("not define")

# %%
df["WklyStudyHours"].isnull().sum()

# %%
df["EthnicGroup"]=df["EthnicGroup"].fillna("not define")

# %%
df["EthnicGroup"].isnull().sum()

# %%
df["ParentEduc"].unique()

# %%
df["ParentEduc"]=df["ParentEduc"].fillna("not define")

# %%
df["ParentEduc"].isnull().sum()

# %%
df["TestPrep"].unique()

# %%
df["TestPrep"]=df["TestPrep"].fillna("not define")

# %%
df["TestPrep"].isnull().sum()

# %%
df["ParentMaritalStatus"].unique()

# %%
df["ParentMaritalStatus"]=df["ParentMaritalStatus"].fillna("not define")

# %%
df["ParentMaritalStatus"].isnull().sum()

# %%
df["IsFirstChild"].unique()

# %%
df["IsFirstChild"]=df["IsFirstChild"].fillna("not define")

# %%
df["IsFirstChild"].isnull().sum()

# %%
df["NrSiblings"].unique()

# %%
df["NrSiblings"]=df["NrSiblings"].fillna("not define")

# %%
df.isnull().sum().sum()

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Exploratory Data Analysis
# </div>

# %%
df.head(2)

# %% [markdown]
# # How many male and female student present in the dataset?

# %%
df["Gender"].value_counts()

# %%
plt.figure(figsize=(5,5))
ax=sns.countplot(data=df,x="Gender")
ax.bar_label(ax.containers[0]);

# %% [markdown]
# ### Insight:
# - Number of **female students** is greater than male students

# %% [markdown]
# # Which group has highest number of student?

# %%
df["EthnicGroup"].value_counts()

# %%
plt.figure(figsize=(4,4))
ax=sns.countplot(x="EthnicGroup",data=df);
ax.bar_label(ax.containers[0]);

# %% [markdown]
# # Insight:
# - **Group C** has the maximum number of students
# - **Group A** has minimum number of students

# %% [markdown]
# # Number of Males and Female student in each group

# %%
sns.countplot(x="EthnicGroup",data=df,hue="Gender");

# %% [markdown]
# # Insight :
# - There is not too much difference between males and female student in each group

# %% [markdown]
# # Parents Education background

# %%
df["ParentEduc"].value_counts()

# %%
sns.countplot(x="ParentEduc",data=df)
plt.xticks(rotation=90);

# %% [markdown]
# # Insight:
# - Highest education background of the parents from **some college**

# %%
df.head(2)

# %% [markdown]
# # Distribution of the lunch type

# %%
sns.countplot(x="LunchType",data=df)

# %% [markdown]
# # Insight:
# - maximum students having the **standard lunch** type

# %%
df.head(5)

# %% [markdown]
# # How many students prepared for the test or not?

# %%
df["TestPrep"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df["TestPrep"].value_counts()
#
# NameError: name 'df' is not defined

# %%
plt.pie(df["TestPrep"].value_counts().values,labels=df["TestPrep"].value_counts().index,autopct="%.2f%%");

# %% [markdown]
# # Insight :
# - only the **34.55%** students completed the test

# %%
df.head()

# %% [markdown]
# # ParentMartialStatus

# %%
sns.countplot(x="ParentMaritalStatus",data=df)

# %% [markdown]
# ### Insight: mostly parents are married

# %%
sns.countplot(x="IsFirstChild",data=df)

# %% [markdown]
# # Number of siblings of each sudents

# %%
df["NrSiblings"].value_counts()

# %%
sns.countplot(x="NrSiblings",data=df)

# %% [markdown]
# # Insight:
# -  frequency of **one** sibling is maximum

# %%
df["WklyStudyHours"].value_counts()

# %%
sns.countplot(x="WklyStudyHours",data=df)

# %% [markdown]
# #### Insight :
# - maximum number of students studied for **5-10 hours**

# %% [markdown]
# # Highest marks in all subjects

# %%
df[["MathScore","ReadingScore","WritingScore"]].agg([max])

# %% [markdown]
# ### insight :
#   - Maximum marks in all subjects is **100**

# %% [markdown]
# # Compare the marks with the parents education

# %%
df.groupby(["ParentEduc"]).agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})

# %%
sns.heatmap(df.groupby(["ParentEduc"]).agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"}),annot=True);
plt.title("Relationship between Parent's Education and Student's score");

# %% [markdown]
# ## Insight :from the above chart we have concluded that the education of the parents have a good impact on their score

# %% [markdown]
# # compare the marks with the ParentMartialStatus

# %%
df.groupby(["ParentMaritalStatus"]).agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})

# %%
sns.heatmap(df.groupby(["ParentMaritalStatus"]).agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"}),annot=True);
plt.title("Relationship Between ParentMartialStatus and student's score");

# %% [markdown]
# ## Insight:from the above chart we have concluded that there is not too much impact of parentmartialstatus on their student scores

# %% [markdown]
# # Relationship Between WklyStudyHours and student's score

# %%
df.groupby(["WklyStudyHours"]).agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})

# %%
sns.heatmap(df.groupby(["WklyStudyHours"]).agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"}),annot=True);
plt.title("Relationship Between WklyStudyHours and student's score");

# %% [markdown]
# ## Insight : from the above chart we concluded that student who studied hrs is greater than 10 having the highest score

# %% [markdown]
# # Is the outliers present in the student'score?

# %%
sns.boxplot(x="MathScore",data=df)

# %%
sns.boxplot(x="ReadingScore",data=df)

# %%
sns.boxplot(x="WritingScore",data=df)

# %% [markdown]
# # Insight :
# - **these charts shows us the outliers of the data**
# - **in math one students even scored zero but in others no one got zero**

# %% [markdown]
# # Compare the student's score with the practice test

# %%
df.groupby(["TestPrep"]).agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"})

# %%
sns.heatmap(df.groupby(["TestPrep"]).agg({"MathScore":"mean","ReadingScore":"mean","WritingScore":"mean"}),annot=True);

# %% [markdown]
# ## Insight: from the above chart we concluded that the student who completed the test preparation got good marks as compared to those who don't completed

# %% [markdown]
# <div style="border-radius:10px; border:#CD5C5C solid; padding: 15px; background-color: #FFFAF1; font-size:100%; text-align:left">
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:pink;
#            font-size:200%;
#            font-family:Serif;
#            letter-spacing:0.5px">
#
# <p style="padding: 10px;
#           color:black;
#           font-size:120%;
#           text-align:center;">
# Conclusion
# </div>

# %% [markdown]
# - Number of **female students** is greater than male students
# -  **Group C** has the maximum number of students
# - **Group A** has minimum number of students
# - There is not too much difference between males and female student in each group
# - Highest education background of the parents from **some college**
# - maximum students having the standard lunch type
# - only the 34.55% students completed the test
# - mostly parents are married¶
# - frequency of **one** sibling is maximum
# - maximum number of students studied for **5-10 hours**
# - Maximum marks in all subjects is **100**
# - education of the parents have a good impact on their score
# - there is not too much impact of parentmartialstatus on their student scores
# - student who studied hrs is greater than 10 having the highest score
# - **these charts shows us the outliers of the data**
# - **in math one students even scored zero but in others no one got zero**
# - student who completed the test preparation got good marks as compared to those who don't completed
